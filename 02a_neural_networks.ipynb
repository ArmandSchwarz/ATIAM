# %% [markdown]
# # Music machine learning - Neural networks
#
# ### Author: Philippe Esling (esling@ircam.fr)
#
# In this course we will cover
# 1. A [quick introduction](#intro) on the code that we will adress and auxiliary functions
# 2. A simple implementation for a [single neuron](#single)
# 3. An implementation of [regression](#implem) using scikit-learn
# 4. Some [common good practices](#practices) in machine learning

# %% [markdown]
# # Introducing neural networks

# %% [markdown]
# In this tutorial, we will cover a more advanced classification algorithm through the use of *neural networks*. The tutorial starts by performing a simple **single neuron** discrimination of two random distributions. Then, we will study the typical **XOR problem** by using a more advanced 2-layer **perceptron**. Finally, we generalize the use of neural networks in order to perform classification on a given set of audio files.

# %% [markdown]
# We are going to use relatively _low-level_ libraries to perform the first exercises (implementing your own neurons)

# %%
import time
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt

# %% [markdown]
# To simplify your work, we provide a first set of functions that provides simple plotting functionnalities (from the `helper_plot.py` file)
#
#   |**File**|*Explanation*|
#   |-------:|:---------|
#   |`plot_boundary`|Plots the decision boundary of a single neuron with 2-dimensional inputs|
#   |`plot_patterns`|Plots (bi-dimensionnal) input patterns|

# %%
from helper_plot import plot_boundary
from helper_plot import plot_patterns

# %% [markdown]
# Remember that a single neuron is only able to learn _linearly separable_ problems. To produce such classes of problems, we provide a script that draw a set of random 2-dimensional points, then choose a random line in this space that will act as the linear frontier between 2 classes (hence defining a linear 2-class problem). The variables that will be used by your code are the following.
#
# ```Matlab
# desired       % classes of the patterns
# inputs        % 2 x n final matrix of random input patterns
# weights       % 2 x 1 vector of neuron weights
# bias          % 1 x 1 vector of bias
# ```
#
# You can execute the code below to see our simple classification problem. (Note that running the same cell multiple times produces a different starting dataset).

# %%
# Number of points to generate
nPats = 30 + np.floor(np.random.rand() * 30);
# Generate 2-dimensional random points
patterns = np.random.rand(2, int(nPats)) * 2 - 1;
# Slope of separating line
slope = np.log(np.random.rand() * 10);
yint = np.random.rand() * 2 - 1;
# Create the indexes for a two-class problem
desired = (patterns[1,:] - patterns[0,:] * slope - yint > 0) * 1;
# Plot the corresponding pattern
fig = plot_patterns(patterns,desired);

# %% [markdown]
# ## Single neuron
#
# For the first parts of the tutorial, we will perform the simplest classification model possible in a neural network setting, a single neuron. We briefly recall here that; given an input vector $ \mathbf{x} \in \mathbb{R}^{n} $, a single neuron computes the function
#
# $$
# \begin{equation}
# \hat{y}=\phi\left(\sum_{i = 1}^{n}w_{i}.x_{i} + b\right)
# %\label{eq1}
# \end{equation}
# $$
#
# with $ \mathbf{w} \in \mathbb{R}^{n} $ a weight vector, $ b $ a bias and $ \phi\left(\cdot\right) $ an *activation function*. Therefore, if we consider the *threshold* activation function ($ \phi_{0}\left(x\right)=1 $ if $ x \geq 0$), a single neuron simply performs an *affine transform* and then a *linear* discrimination of the space. A network will be composed of _layers_ of these neurons, which produce successive computations
#
# <img src="images/02_feedforward_nn.png" align="center"/>
#
# Geometrically, a single neuron computes an hyperplane that separates the space. In order to learn, we have to adjust the weights and know "how much wrong we are". To do so, we consider that we know the desired output $ d $ of a system for a given example $ \mathbf{x} $ (eg. a predicted value for a regression system, a class value for a classification system). Therefore, we define the loss function $ \mathcal{L}_{\mathcal{D}} $ over a whole dataset as
#
# $$
# \begin{equation}
# \mathcal{L}_{\mathcal{D}}=\sum_{j=1}^{k_{\mathcal{D}}}\left\Vert y_{j}-\hat{y}_{j}\right\Vert ^{2}
# %\label{eq2}
# \end{equation}
# $$
#
# In order to know how to change the weights based on the value of the errors, we need to now "how to change it to make it better". Therefore, we should compute the sets of derivatives of the error given each parameter
#
# $$
# \begin{equation}
# \Delta\bar{\mathbf{w}}=\left(\frac{\delta\mathcal{L}}{\delta w_{1}},\ldots,\frac{\delta\mathcal{L}}{\delta w_{n}}\right)
# %\label{eq3}
# \end{equation}
# $$
#
# ***
#
# **Exercise**
#
#   1. Perform the derivatives of the output given a single neuron /calculer le gradient les poids et biais
#   2. Perform the derivatives for the bias as well
#
# ***

# %% [markdown]
# 1. Perform the derivatives of the output given a single neuron /calculer le gradient les poids et biais
# $$
# \begin{align}
# \frac{\partial(\mathcal{L}_{\mathcal{D}})}{\partial(w_k)} &= \frac{\partial(\sum_{j=1}^{k_{\mathcal{D}}}\left\Vert y_{j}-\hat{y}_{j}\right\Vert ^{2})}{\partial(w_k)} \\
#
# &= \frac{\partial(\sum_{j=1}^{k_{\mathcal{D}}}\left\Vert y_{j}-\phi\left(\sum_{i = 1}^{n}w_{i}.x_{ij} + b\right)\right\Vert ^{2})}{\partial(w_k)} \\
#
# &= \sum_{j=1}^{k_{\mathcal{D}}}(-2y_j\frac{\partial(\phi)}{\partial(w_k)} +\frac{\partial(\phi)^2}{\partial(w_k)} )
#
# \end{align}
#
# $$
# or
# $$
# \begin{align}
#
# \frac{\partial(\phi)}{\partial(w_k)} &=  \frac{\partial(\phi\left(\sum_{i = 1}^{n}w_{i}.x_{ij} + b\right))}{\partial(w_k)} \\
#
# &= \phi' \times \frac{\partial((\sum_{i = 1}^{n}w_{j}.x_{ij} + b))}{\partial(w_k)} \\
#
# &= \phi' \times x_{kj}
#
#
# \end{align}
# $$
# avec $\phi' = \frac{d \phi(X)}{d X}$ et
# $$
#
# \frac{\partial(\phi)^2}{\partial(w_k)} = 2 \frac{\partial(\phi)}{\partial(w_i)} \phi
#
# $$
#
# donc
#
# $$
#
# \frac{\partial(\mathcal{L}_{\mathcal{D}})}{\partial(w_k)} = \sum_{j=1}^{k_{\mathcal{D}}} (x_{kj} \phi' 2(\hat{y}_{j} - y_j))
#
# $$

# %% [markdown]
# 2. Perform the derivatives for the bias as well
#
# Pareillement on obtient que
# $$
# \frac{\partial(\mathcal{L}_{\mathcal{D}})}{\partial(b)} = \sum_{j=1}^{k_{\mathcal{D}}} (\phi' 2(\hat{y}_{j} - y_j))
# $$

# %% [markdown]
# ### Training your own neuron
#
# We will start by training a single neuron to learn how to perform this discrimination with a linear problem (so that a single neuron is enough to solve it).

# %%
# Inputs to use
inputs = patterns;
# Initialize the weights
weights = np.random.randn(1, 2);
bias = np.random.randn(1, 1)
#bias = np.array([[0.3]])
# Learning rate
eta = 0.05;
# Weight decay
lambdaW = 0.1

# %% [markdown]
# Now you need to update the following code loop to ensure that your neuron learns to separate between the classes
# ***
#
# **Exercise**
#   1. Update the loop so that it computes the forward propagation error
#   2. Update the loop to perform learning (based on back-propagation)
#   3. Run the learning procedure, which should produce a result similar to that displayed on the website
#   4. Perform multiple re-runs by **tweaking the hyperparameters** (learning rate, weight decay)
#   5. What observations can you make on the learning process?
#   6. (Optional) Change the input patterns, and confirm your observations.
#   6. (Optional) Incorporate the bias in the weights to obtain a **vectorized** code.
#
# ***

# %%
# Plot the corresponding pattern
fig = plot_patterns(patterns,desired);
plt.draw()
# Update loop
for i in range(50):
    
    ######################
    # YOUR CODE GOES HERE
    ######################
    #calcul des gradients, 

    
    Xchap = weights @ inputs + bias
    y_chap = np.zeros(len(desired))
    for j in range(len(y_chap)):
        if Xchap[0][j] >= 0:
            y_chap[j] = 1

    #y_chap2 = (weights @ inputs + bias >0)

    #print(y_chap == y_chap2)
    #print(y_chap)
    #loss = np.sum(np.square(desired - desired_calculer))
    #weights = weights + eta * (desired - desired_calculer) @ inputs.T
    loss = np.sum(np.square(desired - y_chap))
    weights = weights + eta * (desired - y_chap) @ inputs.T
    
    bias = bias + eta * np.sum(desired - y_chap)
    
    print('%2d.  weights = %f, %f, %f' % (i, bias[0, 0], weights[0, 0], weights[0, 1]))
    plot_boundary(np.concatenate((bias, weights), axis=1), i, '--', fig)
    plt.draw()
    time.sleep(0.01)
plot_boundary(np.concatenate((bias, weights), axis=1), i, '-', fig);
# Out:
#  0.  weights = 0.078205, -1.135214, -0.097709
#  1.  weights = 0.178205, -1.111595, 0.031914
#  2.  weights = 0.178205, -1.093220, 0.120047
#  3.  weights = 0.228205, -1.069781, 0.159045
#  4.  weights = 0.278205, -1.046342, 0.198043
#  5.  weights = 0.328205, -1.022902, 0.237042
#  6.  weights = 0.328205, -1.022902, 0.237042
#  7.  weights = 0.328205, -1.022902, 0.237042
#  8.  weights = 0.328205, -1.022902, 0.237042
#  9.  weights = 0.328205, -1.022902, 0.237042
# 10.  weights = 0.328205, -1.022902, 0.237042
# 11.  weights = 0.328205, -1.022902, 0.237042
# 12.  weights = 0.328205, -1.022902, 0.237042
# 13.  weights = 0.328205, -1.022902, 0.237042
# 14.  weights = 0.328205, -1.022902, 0.237042
# 15.  weights = 0.328205, -1.022902, 0.237042
# 16.  weights = 0.328205, -1.022902, 0.237042
# 17.  weights = 0.328205, -1.022902, 0.237042
# 18.  weights = 0.328205, -1.022902, 0.237042
# 19.  weights = 0.328205, -1.022902, 0.237042
# 20.  weights = 0.328205, -1.022902, 0.237042
# 21.  weights = 0.328205, -1.022902, 0.237042
# 22.  weights = 0.328205, -1.022902, 0.237042
# 23.  weights = 0.328205, -1.022902, 0.237042
# 24.  weights = 0.328205, -1.022902, 0.237042
# 25.  weights = 0.328205, -1.022902, 0.237042
# 26.  weights = 0.328205, -1.022902, 0.237042
# 27.  weights = 0.328205, -1.022902, 0.237042
# 28.  weights = 0.328205, -1.022902, 0.237042
# 29.  weights = 0.328205, -1.022902, 0.237042
# 30.  weights = 0.328205, -1.022902, 0.237042
# 31.  weights = 0.328205, -1.022902, 0.237042
# 32.  weights = 0.328205, -1.022902, 0.237042
# 33.  weights = 0.328205, -1.022902, 0.237042
# 34.  weights = 0.328205, -1.022902, 0.237042
# 35.  weights = 0.328205, -1.022902, 0.237042
# 36.  weights = 0.328205, -1.022902, 0.237042
# 37.  weights = 0.328205, -1.022902, 0.237042
# 38.  weights = 0.328205, -1.022902, 0.237042
# 39.  weights = 0.328205, -1.022902, 0.237042
# 40.  weights = 0.328205, -1.022902, 0.237042
# 41.  weights = 0.328205, -1.022902, 0.237042
# 42.  weights = 0.328205, -1.022902, 0.237042
# 43.  weights = 0.328205, -1.022902, 0.237042
# 44.  weights = 0.328205, -1.022902, 0.237042
# 45.  weights = 0.328205, -1.022902, 0.237042
# 46.  weights = 0.328205, -1.022902, 0.237042
# 47.  weights = 0.328205, -1.022902, 0.237042
# 48.  weights = 0.328205, -1.022902, 0.237042
# 49.  weights = 0.328205, -1.022902, 0.237042

# %% [markdown]
# The variables that will be used by your code are the following.
#
# ```Matlab
# patterns          % 2 x n matrix of random points
# desired           % classes of the patterns
# inputs1           % 3 x n final matrix of inputs (accounting for bias)
# nHiddens          % Number of hidden units
# learnRate         % Learning rate parameter
# momentum          % Momentum parameter (bonus)
# weights1          % 1st layer weights
# weights2          % 2nd layer weights
# TSS_Limit         % Sum-squared error limit
# ```

# %% [markdown]
# ## 2-layer XOR problem
#
# In most cases, classification problems are far from being linear. Therefore, we need more advanced methods to be able to compute non-linear class boundaries. The advantage of neural networks is that the same principle can be applied in a *layer-wise* fashion. This allows to further discriminate the space in sub-regions (as seen in the course). We will try to implement the 2-layer *perceptron* that can provide a solution to the infamous XOR problem. The idea is now to have the output of the first neurons to be connected to a set of other neurons. Therefore, if we take back our previous formulation, we have the same output for the first neuron(s) $\hat{y}$, that we will now term as $y^{(1)}$. Then, we feed these outputs to a second layer of neurons, which gives
#
#
# $$
# \begin{equation}
# y^{(2)}=\phi\left(\sum_{i = 1}^{n}w_{i}.y^{(1)}_{i} + b\right)
# %\label{eq6}
# \end{equation}
# $$
#
# Finally, we will rely on the same loss $\mathcal{L_{D}}$ as in the previous exercise, but the outputs used are $y_2$ instead of $y$. As in the previous case, we now need to compute the derivatives of the weights and biases for several layers . However, you should see that some form of generalization might be possible for any number of layer.

# %% [markdown]
# ***
#
# **Exercise**
#   1. Perform the derivatives for the last layer specifically
#   2. Define a generalized derivative for any previous layer
#
# ***

# %% [markdown]
# Avec exactement la même méthode de dérivation que dans le cas de 1 neuronnes, on trouve :
# $$
# \frac{\partial(\mathcal{L}_{\mathcal{D}})}{\partial(w_2)} = \sum_{j=1}^{k_{\mathcal{D}}} (y^1_{kj} \phi' 2(\hat{y}_{j}^2 - desired))
# $$

# %% [markdown]
# ***
# 2
# $$
#
# \frac{\partial(\mathcal{L}_{\mathcal{D}})}{\partial(w_1)} =  \frac{\partial(\mathcal{L}_{\mathcal{D}})}{\partial(y_2)} \cdot \frac{\partial(\phi(O_2))}{\partial(O_2)} \cdot \frac{\partial(O_2)}{\partial(y_1)} \cdot \frac{\partial(\phi(O_1))}{\partial(O_1)} \cdot \frac{\partial(O_1)}{\partial(w_1)}
# $$
#
# or
#
# $$
# \frac{\partial(\mathcal{L}_{\mathcal{D}})}{\partial(y_2)} = \sum_j 2(\hat{y_2} - y_{désirée})
# $$
#
# $$
# \begin{align}
# \frac{\partial(O_2)}{\partial(y_1)} &= \frac{\partial(\sum_{i = 1}^{n}w_{2}.y_{1} + b)}{\partial(y_1)} \\
#
# &= \sum_{i = 1}^{n}w_{2}
# \end{align}
# $$
#
# $$
# \begin{align}
# \frac{\partial(O_1)}{\partial(w_1)} &= \frac{\partial(\sum_{i = 1}^{n}w_{1}.X_{entrée}+ b)}{\partial(w_1)} \\
#
# &= X_{entrée}
#
# \end{align}
# $$
#
# donc
#
# $$
# \frac{\partial(\mathcal{L}_{\mathcal{D}})}{\partial(w_1)} = \sum_j 2(\hat{y_2} - y_{désirée}) . \phi'(O_2) . \sum_{i = 1}^{n}w_{2} . \phi'(O_1) . X_{entrée}
#
# $$

# %% [markdown]
# or comme $\phi$ est une sigmoid on a que
# $ \frac{d \phi(O_1)}{d O_1} =  \phi(O_1) (1 - \phi(O_1))$
#
# Ainsi en réarrangeant les termes on trouves que :
# $$
# \frac{\partial(\mathcal{L}_{\mathcal{D}})}{\partial(w_1)} = \frac{\partial(\mathcal{L}_{\mathcal{D}})}{\partial(w_2)} . (\phi(O_1) - O_1) .\sum_{i = 1}^{n}w_{2} . X_{entrée}
# $$
#
# Ainsi on a trouvé une formule récursive qu'on peut généraliser aux réseaux à plus de 2 couches

# %% [markdown]
# We can construct the prototypical set of XOR values by using the following code (note that this is the most simple case, but still this is typically a problem that cannot be solved by a _linear classifier_

# %%
patterns = np.array([[-1, -1],[-1,  1],[1, -1],[1,  1]]).transpose() # Input patterns
desired = np.array([0, 1, 1, 0])  # Corresponding classes
out_patterns = []
out_desired = []
n_augment = 50
for p in range(4):
    rep_pat = np.repeat(patterns[:, p][:, np.newaxis], n_augment, axis=1)
    out_patterns.append(np.random.randn(2, n_augment) * 0.2 + rep_pat)
    out_desired.append(np.repeat([desired[p]], n_augment))
out_patterns = (np.concatenate(out_patterns, axis=1))
out_desired = (np.concatenate(out_desired))
# Initialize based on their sizes
patterns = out_patterns
desired = out_desired
nInputs = patterns.shape[0]
nOutputs = 1
inputs = patterns
nPat = patterns.shape[1]
# First plot the patterns
fig = plot_patterns(out_patterns, out_desired);

# %%
nHiddens = 2           # Number of hidden units
learnRate = 0.001       # Learning rate parameter
momentum = 0.1         # Momentum parameter
# Overall input patterns
inputs = patterns
TSS_Limit = 0.002                                           # Sum-squared error limit
# Learning rate
eta = 0.01

# %% [markdown]
# ***
#
# **Exercise**
#
#   1. Update the forward propagation and error computation (compared to desired).
#   2. Update the back-propagation part to learn the weights of both layers.
#   3. Run the learning, which should produce a result similar to that displayed below.
#   4. Perform multiple re-runs of the learning procedure (re-launching with different initializations)
#   5. What observations can you make on the learning process?
#   6. What happens if you initialize all weights to zeros?
#   7. (Optional) Implement the *sparsity* constraint in your neural network.
#   7. (Optional) Implement the *weight decay* constraint in your network.
#   7. (Optional) Add the *momentum* to the learning procedure.
#
# *For optional questions, please look after the first code box for more information*
#
# ***

# %%
# Function for computing the Sigmoid activation
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def dsigmoid(a):
    return a * (1.0 - a)
# Function for computing the ReL

# %%
# Weights of first and second layer
weights1 = (np.random.randn(nHiddens, nInputs) - 0.5)      # 1st layer weights
weights2 = (np.random.randn(nOutputs, nHiddens) - 0.5)     # 2nd layer weights
bias1 = (np.random.randn(nHiddens, 1) - 0.5)               # 1st layer biases
bias2 = (np.random.randn(nOutputs, 1) - 0.5)               # 2nd layer biases
# First plot the patterns

#weights1 = np.zeros_like(weights1)
#weights2 = np.zeros_like(weights2)
#bias1 = np.zeros_like(bias1)
#bias2 = np.zeros_like(bias2)

fig = plot_patterns(patterns, desired);
# Iterate for a fixed number of iterations
for epoch in range(10000):
  
    #forward pass
    
    X_1 = weights1 @ inputs + bias1
    Y_1 = sigmoid(X_1)
    X_2 = weights2 @ Y_1 + bias2
    Y_2 = sigmoid(X_2)
    TSS = np.sum(np.abs(Y_2 - desired)**2)


    d_1 = 2 * (Y_2 - desired) * dsigmoid(Y_2)
    d_2 = np.dot(weights2.T, d_1) * dsigmoid(Y_1)
    d_3 = np.dot(d_2,inputs.T)
    #backward propagation

    bias1 = bias1 - eta * np.sum(d_2,axis=1)[:,np.newaxis]
    weights1 = weights1 - eta * d_3
    #print(weights1.shape)

    d_4 = np.dot(d_1,Y_1.T)
    weights2 = weights2 - eta * d_4

    #print(np.sum(d_1,axis=1))
    bias2 = bias2 - eta * np.sum(d_1,axis=1)[:,np.newaxis]

    
    print('Epoch %3d:  Error = %f' % (epoch, TSS));
    if TSS < TSS_Limit:
        break
    if (epoch - 1 % 20)==0:
        #print('e')
        plot_boundary(np.concatenate((bias2, weights2), axis=1), epoch, '--', fig)

plot_boundary(np.concatenate((bias1, weights1), axis=1), epoch, '-', fig)
# Out:
# Epoch   0:  Error = 86.764369
# Epoch   1:  Error = 84.794883
# Epoch   2:  Error = 82.369520
# Epoch   3:  Error = 79.380883
# Epoch   4:  Error = 75.729486
# Epoch   5:  Error = 71.376763
# Epoch   6:  Error = 66.445090
# Epoch   7:  Error = 61.334756
# Epoch   8:  Error = 56.713415
# Epoch   9:  Error = 53.207550
# Epoch  10:  Error = 50.992641
# Epoch  11:  Error = 49.780707
# Epoch  12:  Error = 49.161464
# Epoch  13:  Error = 48.837229
# Epoch  14:  Error = 48.645752
# Epoch  15:  Error = 48.509919
# Epoch  16:  Error = 48.395314
# Epoch  17:  Error = 48.286971
# Epoch  18:  Error = 48.178423
# Epoch  19:  Error = 48.066855
# Epoch  20:  Error = 47.951022
# Epoch  21:  Error = 47.830361
# Epoch  22:  Error = 47.704623
# Epoch  23:  Error = 47.573708
# Epoch  24:  Error = 47.437608
# Epoch  25:  Error = 47.296374
# Epoch  26:  Error = 47.150106
# Epoch  27:  Error = 46.998946
# Epoch  28:  Error = 46.843077
# Epoch  29:  Error = 46.682717
# Epoch  30:  Error = 46.518116
# Epoch  31:  Error = 46.349554
# Epoch  32:  Error = 46.177331
# Epoch  33:  Error = 46.001767
# Epoch  34:  Error = 45.823192
# Epoch  35:  Error = 45.641943
# Epoch  36:  Error = 45.458357
# Epoch  37:  Error = 45.272767
# Epoch  38:  Error = 45.085494
# Epoch  39:  Error = 44.896845
# Epoch  40:  Error = 44.707107
# Epoch  41:  Error = 44.516545
# Epoch  42:  Error = 44.325399
# Epoch  43:  Error = 44.133884
# Epoch  44:  Error = 43.942183
# Epoch  45:  Error = 43.750452
# Epoch  46:  Error = 43.558817
# Epoch  47:  Error = 43.367375
# Epoch  48:  Error = 43.176193
# Epoch  49:  Error = 42.985310
# Epoch  50:  Error = 42.794737
# Epoch  51:  Error = 42.604459
# Epoch  52:  Error = 42.414433
# Epoch  53:  Error = 42.224595
# Epoch  54:  Error = 42.034852
# Epoch  55:  Error = 41.845094
# Epoch  56:  Error = 41.655183
# Epoch  57:  Error = 41.464964
# Epoch  58:  Error = 41.274260
# Epoch  59:  Error = 41.082874
# Epoch  60:  Error = 40.890592
# Epoch  61:  Error = 40.697178
# Epoch  62:  Error = 40.502383
# Epoch  63:  Error = 40.305935
# Epoch  64:  Error = 40.107551
# Epoch  65:  Error = 39.906929
# Epoch  66:  Error = 39.703751
# Epoch  67:  Error = 39.497685
# Epoch  68:  Error = 39.288387
# Epoch  69:  Error = 39.075496
# Epoch  70:  Error = 38.858641
# Epoch  71:  Error = 38.637438
# Epoch  72:  Error = 38.411496
# Epoch  73:  Error = 38.180411
# Epoch  74:  Error = 37.943774
# Epoch  75:  Error = 37.701170
# Epoch  76:  Error = 37.452180
# Epoch  77:  Error = 37.196384
# Epoch  78:  Error = 36.933363
# Epoch  79:  Error = 36.662702
# Epoch  80:  Error = 36.383995
# Epoch  81:  Error = 36.096844
# Epoch  82:  Error = 35.800869
# Epoch  83:  Error = 35.495707
# Epoch  84:  Error = 35.181024
# Epoch  85:  Error = 34.856510
# Epoch  86:  Error = 34.521894
# Epoch  87:  Error = 34.176946
# Epoch  88:  Error = 33.821482
# Epoch  89:  Error = 33.455371
# Epoch  90:  Error = 33.078543
# Epoch  91:  Error = 32.690989
# Epoch  92:  Error = 32.292774
# Epoch  93:  Error = 31.884033
# Epoch  94:  Error = 31.464982
# Epoch  95:  Error = 31.035917
# Epoch  96:  Error = 30.597214
# Epoch  97:  Error = 30.149331
# Epoch  98:  Error = 29.692809
# Epoch  99:  Error = 29.228264
# Epoch 100:  Error = 28.756384
# Epoch 101:  Error = 28.277928
# Epoch 102:  Error = 27.793709
# Epoch 103:  Error = 27.304597
# Epoch 104:  Error = 26.811500
# Epoch 105:  Error = 26.315359
# Epoch 106:  Error = 25.817136
# Epoch 107:  Error = 25.317800
# Epoch 108:  Error = 24.818322
# Epoch 109:  Error = 24.319660
# Epoch 110:  Error = 23.822748
# Epoch 197:  Error = 5.010362
# Epoch 198:  Error = 4.952070
# Epoch 199:  Error = 4.894959
# Epoch 200:  Error = 4.838998
# Epoch 201:  Error = 4.784155
# Epoch 202:  Error = 4.730398
# Epoch 203:  Error = 4.677700
# Epoch 204:  Error = 4.626030
# Epoch 205:  Error = 4.575363
# Epoch 206:  Error = 4.525670
# Epoch 207:  Error = 4.476926
# Epoch 208:  Error = 4.429106
# Epoch 209:  Error = 4.382186
# Epoch 210:  Error = 4.336143
# Epoch 211:  Error = 4.290954
# Epoch 212:  Error = 4.246597
# Epoch 213:  Error = 4.203051
# Epoch 214:  Error = 4.160295
# Epoch 215:  Error = 4.118311
# Epoch 216:  Error = 4.077077
# Epoch 217:  Error = 4.036576
# Epoch 218:  Error = 3.996790
# Epoch 219:  Error = 3.957701
# Epoch 220:  Error = 3.919292
# Epoch 221:  Error = 3.881547
# Epoch 222:  Error = 3.844450
# Epoch 223:  Error = 3.807985
# Epoch 224:  Error = 3.772137
# Epoch 225:  Error = 3.736892
# Epoch 226:  Error = 3.702235
# Epoch 227:  Error = 3.668153
# Epoch 228:  Error = 3.634633
# Epoch 229:  Error = 3.601661
# Epoch 230:  Error = 3.569226
# Epoch 231:  Error = 3.537314
# Epoch 232:  Error = 3.505914
# Epoch 233:  Error = 3.475015
# Epoch 234:  Error = 3.444605
# Epoch 235:  Error = 3.414674
# Epoch 236:  Error = 3.385210
# Epoch 237:  Error = 3.356204
# Epoch 238:  Error = 3.327646
# Epoch 239:  Error = 3.299525
# Epoch 240:  Error = 3.271834
# Epoch 241:  Error = 3.244561
# Epoch 242:  Error = 3.217699
# Epoch 243:  Error = 3.191238
# Epoch 244:  Error = 3.165171
# Epoch 245:  Error = 3.139489
# Epoch 246:  Error = 3.114184
# Epoch 247:  Error = 3.089248
# Epoch 248:  Error = 3.064674
# Epoch 249:  Error = 3.040453
# Epoch 250:  Error = 3.016580
# Epoch 251:  Error = 2.993047
# Epoch 252:  Error = 2.969847
# Epoch 253:  Error = 2.946973
# Epoch 254:  Error = 2.924420
# Epoch 255:  Error = 2.902180
# Epoch 256:  Error = 2.880247
# Epoch 257:  Error = 2.858616
# Epoch 258:  Error = 2.837281
# Epoch 259:  Error = 2.816235
# Epoch 260:  Error = 2.795474
# Epoch 261:  Error = 2.774992
# Epoch 262:  Error = 2.754783
# Epoch 263:  Error = 2.734842
# Epoch 264:  Error = 2.715165
# Epoch 265:  Error = 2.695746
# Epoch 266:  Error = 2.676581
# Epoch 267:  Error = 2.657665
# Epoch 268:  Error = 2.638993
# Epoch 269:  Error = 2.620560
# Epoch 270:  Error = 2.602364
# Epoch 271:  Error = 2.584398
# Epoch 272:  Error = 2.566659
# Epoch 273:  Error = 2.549143
# Epoch 274:  Error = 2.531846
# Epoch 275:  Error = 2.514764
# Epoch 276:  Error = 2.497894
# Epoch 277:  Error = 2.481230
# Epoch 278:  Error = 2.464771
# Epoch 279:  Error = 2.448512
# Epoch 280:  Error = 2.432449
# Epoch 281:  Error = 2.416581
# Epoch 282:  Error = 2.400902
# Epoch 283:  Error = 2.385410
# Epoch 284:  Error = 2.370102
# Epoch 285:  Error = 2.354974
# Epoch 286:  Error = 2.340024
# Epoch 287:  Error = 2.325249
# Epoch 288:  Error = 2.310645
# Epoch 289:  Error = 2.296210
# Epoch 290:  Error = 2.281941
# Epoch 291:  Error = 2.267835
# Epoch 292:  Error = 2.253890
# Epoch 293:  Error = 2.240103
# Epoch 294:  Error = 2.226471
# Epoch 295:  Error = 2.212993
# Epoch 296:  Error = 2.199665
# Epoch 297:  Error = 2.186485
# Epoch 298:  Error = 2.173450
# Epoch 299:  Error = 2.160559
# Epoch 300:  Error = 2.147810
# Epoch 301:  Error = 2.135199
# Epoch 302:  Error = 2.122725
# Epoch 303:  Error = 2.110385
# Epoch 304:  Error = 2.098179
# Epoch 305:  Error = 2.086102
# Epoch 306:  Error = 2.074155
# Epoch 307:  Error = 2.062334
# Epoch 308:  Error = 2.050637
# Epoch 309:  Error = 2.039063
# Epoch 310:  Error = 2.027611
# Epoch 311:  Error = 2.016277
# Epoch 312:  Error = 2.005061
# Epoch 313:  Error = 1.993960
# Epoch 314:  Error = 1.982973
# Epoch 315:  Error = 1.972098
# Epoch 316:  Error = 1.961334
# Epoch 317:  Error = 1.950679
# Epoch 318:  Error = 1.940131
# Epoch 319:  Error = 1.929689
# Epoch 320:  Error = 1.919352
# Epoch 321:  Error = 1.909117
# Epoch 322:  Error = 1.898983
# Epoch 323:  Error = 1.888950
# Epoch 324:  Error = 1.879014
# Epoch 325:  Error = 1.869176
# Epoch 326:  Error = 1.859434
# Epoch 327:  Error = 1.849786
# Epoch 328:  Error = 1.840231
# Epoch 329:  Error = 1.830767
# Epoch 330:  Error = 1.821395
# Epoch 331:  Error = 1.812111
# Epoch 332:  Error = 1.802916
# Epoch 333:  Error = 1.793807
# Epoch 334:  Error = 1.784784
# Epoch 335:  Error = 1.775845
# Epoch 336:  Error = 1.766990
# Epoch 337:  Error = 1.758217
# Epoch 338:  Error = 1.749526
# Epoch 339:  Error = 1.740914
# Epoch 340:  Error = 1.732381
# Epoch 341:  Error = 1.723926
# Epoch 342:  Error = 1.715548
# Epoch 343:  Error = 1.707246
# Epoch 344:  Error = 1.699019
# Epoch 345:  Error = 1.690866
# Epoch 346:  Error = 1.682786
# Epoch 347:  Error = 1.674778
# Epoch 348:  Error = 1.666841
# Epoch 349:  Error = 1.658974
# Epoch 350:  Error = 1.651177
# Epoch 351:  Error = 1.643448
# Epoch 352:  Error = 1.635786
# Epoch 353:  Error = 1.628191
# Epoch 354:  Error = 1.620662
# Epoch 355:  Error = 1.613198
# Epoch 356:  Error = 1.605799
# Epoch 357:  Error = 1.598463
# Epoch 358:  Error = 1.591189
# Epoch 359:  Error = 1.583977
# Epoch 360:  Error = 1.576827
# Epoch 361:  Error = 1.569737
# Epoch 362:  Error = 1.562706
# Epoch 363:  Error = 1.555735
# Epoch 364:  Error = 1.548821
# Epoch 365:  Error = 1.541965
# Epoch 366:  Error = 1.535166
# Epoch 367:  Error = 1.528423
# Epoch 368:  Error = 1.521736
# Epoch 369:  Error = 1.515103
# Epoch 370:  Error = 1.508524
# Epoch 371:  Error = 1.501999
# Epoch 372:  Error = 1.495527
# Epoch 373:  Error = 1.489107
# Epoch 374:  Error = 1.482739
# Epoch 375:  Error = 1.476421
# Epoch 376:  Error = 1.470155
# Epoch 377:  Error = 1.463938
# Epoch 378:  Error = 1.457770
# Epoch 379:  Error = 1.451651
# Epoch 380:  Error = 1.445580
# Epoch 381:  Error = 1.439557
# Epoch 382:  Error = 1.433581
# Epoch 383:  Error = 1.427652
# Epoch 384:  Error = 1.421768
# Epoch 385:  Error = 1.415930
# Epoch 386:  Error = 1.410137
# Epoch 387:  Error = 1.404389
# Epoch 388:  Error = 1.398684
# Epoch 389:  Error = 1.393023
# Epoch 390:  Error = 1.387406
# Epoch 391:  Error = 1.381830
# Epoch 392:  Error = 1.376297
# Epoch 393:  Error = 1.370805
# Epoch 394:  Error = 1.365355
# Epoch 395:  Error = 1.359945
# Epoch 396:  Error = 1.354576
# Epoch 397:  Error = 1.349246
# Epoch 398:  Error = 1.343956
# Epoch 399:  Error = 1.338705
# Epoch 400:  Error = 1.333492
# Epoch 401:  Error = 1.328318
# Epoch 402:  Error = 1.323181
# Epoch 403:  Error = 1.318082
# Epoch 404:  Error = 1.313020
# Epoch 405:  Error = 1.307994
# Epoch 406:  Error = 1.303005
# Epoch 407:  Error = 1.298051
# Epoch 408:  Error = 1.293133
# Epoch 409:  Error = 1.288250
# Epoch 410:  Error = 1.283401
# Epoch 411:  Error = 1.278587
# Epoch 412:  Error = 1.273807
# Epoch 413:  Error = 1.269061
# Epoch 414:  Error = 1.264348
# Epoch 415:  Error = 1.259668
# Epoch 416:  Error = 1.255021
# Epoch 417:  Error = 1.250405
# Epoch 418:  Error = 1.245822
# Epoch 419:  Error = 1.241271
# Epoch 420:  Error = 1.236751
# Epoch 421:  Error = 1.232262
# Epoch 422:  Error = 1.227803
# Epoch 423:  Error = 1.223375
# Epoch 424:  Error = 1.218977
# Epoch 425:  Error = 1.214609
# Epoch 426:  Error = 1.210271
# Epoch 427:  Error = 1.205962
# Epoch 428:  Error = 1.201681
# Epoch 429:  Error = 1.197430
# Epoch 430:  Error = 1.193206
# Epoch 431:  Error = 1.189011
# Epoch 432:  Error = 1.184844
# Epoch 433:  Error = 1.180704
# Epoch 434:  Error = 1.176592
# Epoch 435:  Error = 1.172506
# Epoch 436:  Error = 1.168448
# Epoch 437:  Error = 1.164416
# Epoch 438:  Error = 1.160410
# Epoch 439:  Error = 1.156430
# Epoch 440:  Error = 1.152476
# Epoch 441:  Error = 1.148548
# Epoch 442:  Error = 1.144645
# Epoch 443:  Error = 1.140767
# Epoch 444:  Error = 1.136913
# Epoch 445:  Error = 1.133085
# Epoch 446:  Error = 1.129280
# Epoch 447:  Error = 1.125500
# Epoch 448:  Error = 1.121744
# Epoch 449:  Error = 1.118011
# Epoch 450:  Error = 1.114302
# Epoch 451:  Error = 1.110617
# Epoch 452:  Error = 1.106954
# Epoch 453:  Error = 1.103314
# Epoch 454:  Error = 1.099697
# Epoch 455:  Error = 1.096102
# Epoch 456:  Error = 1.092530
# Epoch 457:  Error = 1.088979
# Epoch 458:  Error = 1.085450
# Epoch 459:  Error = 1.081943
# Epoch 460:  Error = 1.078458
# Epoch 461:  Error = 1.074993
# Epoch 462:  Error = 1.071550
# Epoch 463:  Error = 1.068128
# Epoch 464:  Error = 1.064726
# Epoch 465:  Error = 1.061345
# Epoch 466:  Error = 1.057984
# Epoch 467:  Error = 1.054643
# Epoch 468:  Error = 1.051322
# Epoch 469:  Error = 1.048021
# Epoch 470:  Error = 1.044740
# Epoch 471:  Error = 1.041478
# Epoch 472:  Error = 1.038235
# Epoch 473:  Error = 1.035012
# Epoch 474:  Error = 1.031808
# Epoch 475:  Error = 1.028622
# Epoch 476:  Error = 1.025455
# Epoch 477:  Error = 1.022306
# Epoch 478:  Error = 1.019176
# Epoch 479:  Error = 1.016064
# Epoch 480:  Error = 1.012970
# Epoch 481:  Error = 1.009894
# Epoch 482:  Error = 1.006835
# Epoch 483:  Error = 1.003794
# Epoch 484:  Error = 1.000771
# Epoch 485:  Error = 0.997765
# Epoch 486:  Error = 0.994776
# Epoch 487:  Error = 0.991803
# Epoch 488:  Error = 0.988848
# Epoch 489:  Error = 0.985910
# Epoch 490:  Error = 0.982988
# Epoch 491:  Error = 0.980082
# Epoch 492:  Error = 0.977193
# Epoch 493:  Error = 0.974320
# Epoch 494:  Error = 0.971463
# Epoch 495:  Error = 0.968621
# Epoch 496:  Error = 0.965796
# Epoch 497:  Error = 0.962986
# Epoch 498:  Error = 0.960192
# Epoch 499:  Error = 0.957413
# Epoch 500:  Error = 0.954649
# Epoch 501:  Error = 0.951901
# Epoch 502:  Error = 0.949168
# Epoch 503:  Error = 0.946449
# Epoch 504:  Error = 0.943745
# Epoch 505:  Error = 0.941056
# Epoch 506:  Error = 0.938382
# Epoch 507:  Error = 0.935722
# Epoch 508:  Error = 0.933076
# Epoch 509:  Error = 0.930444
# Epoch 510:  Error = 0.927827
# Epoch 511:  Error = 0.925224
# Epoch 512:  Error = 0.922634
# Epoch 513:  Error = 0.920058
# Epoch 514:  Error = 0.917496
# Epoch 515:  Error = 0.914948
# Epoch 516:  Error = 0.912413
# Epoch 517:  Error = 0.909891
# Epoch 518:  Error = 0.907382
# Epoch 519:  Error = 0.904887
# Epoch 520:  Error = 0.902405
# Epoch 521:  Error = 0.899935
# Epoch 522:  Error = 0.897479
# Epoch 523:  Error = 0.895035
# Epoch 524:  Error = 0.892604
# Epoch 525:  Error = 0.890185
# Epoch 526:  Error = 0.887779
# Epoch 527:  Error = 0.885385
# Epoch 528:  Error = 0.883004
# Epoch 529:  Error = 0.880635
# Epoch 530:  Error = 0.878278
# Epoch 531:  Error = 0.875932
# Epoch 532:  Error = 0.873599
# Epoch 533:  Error = 0.871278
# Epoch 534:  Error = 0.868968
# Epoch 535:  Error = 0.866670
# Epoch 536:  Error = 0.864384
# Epoch 537:  Error = 0.862109
# Epoch 538:  Error = 0.859845
# Epoch 539:  Error = 0.857593
# Epoch 540:  Error = 0.855352
# Epoch 541:  Error = 0.853122
# Epoch 542:  Error = 0.850903
# Epoch 543:  Error = 0.848695
# Epoch 544:  Error = 0.846498
# Epoch 545:  Error = 0.844312
# Epoch 546:  Error = 0.842137
# Epoch 547:  Error = 0.839972
# Epoch 548:  Error = 0.837818
# Epoch 549:  Error = 0.835674
# Epoch 550:  Error = 0.833541
# Epoch 551:  Error = 0.831419
# Epoch 552:  Error = 0.829306
# Epoch 553:  Error = 0.827204
# Epoch 554:  Error = 0.825112
# Epoch 555:  Error = 0.823030
# Epoch 556:  Error = 0.820958
# Epoch 557:  Error = 0.818896
# Epoch 558:  Error = 0.816844
# Epoch 559:  Error = 0.814801
# Epoch 560:  Error = 0.812769
# Epoch 561:  Error = 0.810746
# Epoch 562:  Error = 0.808732
# Epoch 563:  Error = 0.806728
# Epoch 564:  Error = 0.804734
# Epoch 565:  Error = 0.802749
# Epoch 566:  Error = 0.800773
# Epoch 567:  Error = 0.798807
# Epoch 568:  Error = 0.796850
# Epoch 569:  Error = 0.794902
# Epoch 570:  Error = 0.792963
# Epoch 571:  Error = 0.791033
# Epoch 572:  Error = 0.789112
# Epoch 573:  Error = 0.787200
# Epoch 574:  Error = 0.785297
# Epoch 575:  Error = 0.783402
# Epoch 576:  Error = 0.781517
# Epoch 577:  Error = 0.779639
# Epoch 578:  Error = 0.777771
# Epoch 579:  Error = 0.775911
# Epoch 580:  Error = 0.774060
# Epoch 581:  Error = 0.772217
# Epoch 582:  Error = 0.770382
# Epoch 583:  Error = 0.768556
# Epoch 584:  Error = 0.766737
# Epoch 585:  Error = 0.764928
# Epoch 586:  Error = 0.763126
# Epoch 587:  Error = 0.761332
# Epoch 588:  Error = 0.759547
# Epoch 589:  Error = 0.757769
# Epoch 590:  Error = 0.755999
# Epoch 591:  Error = 0.754238
# Epoch 592:  Error = 0.752484
# Epoch 593:  Error = 0.750738
# Epoch 594:  Error = 0.748999
# Epoch 595:  Error = 0.747269
# Epoch 596:  Error = 0.745546
# Epoch 597:  Error = 0.743830
# Epoch 598:  Error = 0.742122
# Epoch 599:  Error = 0.740422
# Epoch 600:  Error = 0.738729
# Epoch 601:  Error = 0.737043
# Epoch 602:  Error = 0.735365
# Epoch 603:  Error = 0.733694
# Epoch 604:  Error = 0.732030
# Epoch 605:  Error = 0.730374
# Epoch 606:  Error = 0.728724
# Epoch 607:  Error = 0.727082
# Epoch 608:  Error = 0.725447
# Epoch 609:  Error = 0.723819
# Epoch 610:  Error = 0.722197
# Epoch 611:  Error = 0.720583
# Epoch 612:  Error = 0.718976
# Epoch 613:  Error = 0.717375
# Epoch 614:  Error = 0.715782
# Epoch 615:  Error = 0.714195
# Epoch 616:  Error = 0.712615
# Epoch 617:  Error = 0.711041
# Epoch 618:  Error = 0.709474
# Epoch 619:  Error = 0.707914
# Epoch 620:  Error = 0.706360
# Epoch 621:  Error = 0.704813
# Epoch 622:  Error = 0.703272
# Epoch 623:  Error = 0.701738
# Epoch 624:  Error = 0.700210
# Epoch 625:  Error = 0.698689
# Epoch 626:  Error = 0.697174
# Epoch 627:  Error = 0.695665
# Epoch 628:  Error = 0.694162
# Epoch 629:  Error = 0.692666
# Epoch 630:  Error = 0.691175
# Epoch 631:  Error = 0.689691
# Epoch 632:  Error = 0.688213
# Epoch 633:  Error = 0.686741
# Epoch 634:  Error = 0.685275
# Epoch 635:  Error = 0.683815
# Epoch 636:  Error = 0.682361
# Epoch 637:  Error = 0.680913
# Epoch 638:  Error = 0.679471
# Epoch 639:  Error = 0.678034
# Epoch 640:  Error = 0.676604
# Epoch 641:  Error = 0.675179
# Epoch 642:  Error = 0.673760
# Epoch 643:  Error = 0.672347
# Epoch 644:  Error = 0.670939
# Epoch 645:  Error = 0.669537
# Epoch 646:  Error = 0.668140
# Epoch 647:  Error = 0.666749
# Epoch 648:  Error = 0.665364
# Epoch 649:  Error = 0.663984
# Epoch 650:  Error = 0.662610
# Epoch 651:  Error = 0.661241
# Epoch 652:  Error = 0.659878
# Epoch 653:  Error = 0.658519
# Epoch 654:  Error = 0.657167
# Epoch 655:  Error = 0.655819
# Epoch 656:  Error = 0.654477
# Epoch 657:  Error = 0.653140
# Epoch 658:  Error = 0.651809
# Epoch 659:  Error = 0.650482
# Epoch 660:  Error = 0.649161
# Epoch 661:  Error = 0.647845
# Epoch 662:  Error = 0.646534
# Epoch 663:  Error = 0.645228
# Epoch 664:  Error = 0.643927
# Epoch 665:  Error = 0.642631
# Epoch 666:  Error = 0.641340
# Epoch 667:  Error = 0.640054
# Epoch 668:  Error = 0.638773
# Epoch 669:  Error = 0.637497
# Epoch 670:  Error = 0.636226
# Epoch 671:  Error = 0.634959
# Epoch 672:  Error = 0.633698
# Epoch 673:  Error = 0.632441
# Epoch 674:  Error = 0.631189
# Epoch 675:  Error = 0.629942
# Epoch 676:  Error = 0.628699
# Epoch 677:  Error = 0.627462
# Epoch 678:  Error = 0.626229
# Epoch 679:  Error = 0.625000
# Epoch 680:  Error = 0.623776
# Epoch 681:  Error = 0.622557
# Epoch 682:  Error = 0.621342
# Epoch 683:  Error = 0.620132
# Epoch 684:  Error = 0.618927
# Epoch 685:  Error = 0.617725
# Epoch 686:  Error = 0.616529
# Epoch 687:  Error = 0.615336
# Epoch 688:  Error = 0.614149
# Epoch 689:  Error = 0.612965
# Epoch 690:  Error = 0.611786
# Epoch 691:  Error = 0.610612
# Epoch 692:  Error = 0.609441
# Epoch 693:  Error = 0.608275
# Epoch 694:  Error = 0.607113
# Epoch 695:  Error = 0.605956
# Epoch 696:  Error = 0.604802
# Epoch 697:  Error = 0.603653
# Epoch 698:  Error = 0.602508
# Epoch 699:  Error = 0.601368
# Epoch 700:  Error = 0.600231
# Epoch 701:  Error = 0.599099
# Epoch 702:  Error = 0.597970
# Epoch 703:  Error = 0.596846
# Epoch 704:  Error = 0.595726
# Epoch 705:  Error = 0.594609
# Epoch 706:  Error = 0.593497
# Epoch 707:  Error = 0.592389
# Epoch 708:  Error = 0.591285
# Epoch 709:  Error = 0.590184
# Epoch 710:  Error = 0.589088
# Epoch 711:  Error = 0.587995
# Epoch 712:  Error = 0.586907
# Epoch 713:  Error = 0.585822
# Epoch 714:  Error = 0.584741
# Epoch 715:  Error = 0.583664
# Epoch 716:  Error = 0.582591
# Epoch 717:  Error = 0.581521
# Epoch 718:  Error = 0.580456
# Epoch 719:  Error = 0.579394
# Epoch 720:  Error = 0.578336
# Epoch 721:  Error = 0.577281
# Epoch 722:  Error = 0.576230
# Epoch 723:  Error = 0.575183
# Epoch 724:  Error = 0.574140
# Epoch 725:  Error = 0.573100
# Epoch 726:  Error = 0.572063
# Epoch 727:  Error = 0.571031
# Epoch 728:  Error = 0.570002
# Epoch 729:  Error = 0.568976
# Epoch 730:  Error = 0.567954
# Epoch 731:  Error = 0.566936
# Epoch 732:  Error = 0.565921
# Epoch 733:  Error = 0.564909
# Epoch 734:  Error = 0.563901
# Epoch 735:  Error = 0.562897
# Epoch 736:  Error = 0.561896
# Epoch 737:  Error = 0.560898
# Epoch 738:  Error = 0.559904
# Epoch 739:  Error = 0.558913
# Epoch 740:  Error = 0.557925
# Epoch 741:  Error = 0.556941
# Epoch 742:  Error = 0.555960
# Epoch 743:  Error = 0.554983
# Epoch 744:  Error = 0.554008
# Epoch 745:  Error = 0.553037
# Epoch 746:  Error = 0.552070
# Epoch 747:  Error = 0.551105
# Epoch 748:  Error = 0.550144
# Epoch 749:  Error = 0.549186
# Epoch 750:  Error = 0.548231
# Epoch 751:  Error = 0.547280
# Epoch 752:  Error = 0.546331
# Epoch 753:  Error = 0.545386
# Epoch 754:  Error = 0.544444
# Epoch 755:  Error = 0.543505
# Epoch 756:  Error = 0.542569
# Epoch 757:  Error = 0.541636
# Epoch 758:  Error = 0.540707
# Epoch 759:  Error = 0.539780
# Epoch 760:  Error = 0.538856
# Epoch 761:  Error = 0.537936
# Epoch 762:  Error = 0.537018
# Epoch 763:  Error = 0.536104
# Epoch 764:  Error = 0.535192
# Epoch 765:  Error = 0.534284
# Epoch 766:  Error = 0.533378
# Epoch 767:  Error = 0.532475
# Epoch 768:  Error = 0.531576
# Epoch 769:  Error = 0.530679
# Epoch 770:  Error = 0.529785
# Epoch 771:  Error = 0.528894
# Epoch 772:  Error = 0.528006
# Epoch 773:  Error = 0.527121
# Epoch 774:  Error = 0.526238
# Epoch 775:  Error = 0.525359
# Epoch 776:  Error = 0.524482
# Epoch 777:  Error = 0.523608
# Epoch 778:  Error = 0.522737
# Epoch 779:  Error = 0.521869
# Epoch 780:  Error = 0.521003
# Epoch 781:  Error = 0.520140
# Epoch 782:  Error = 0.519280
# Epoch 783:  Error = 0.518423
# Epoch 784:  Error = 0.517568
# Epoch 785:  Error = 0.516717
# Epoch 786:  Error = 0.515867
# Epoch 787:  Error = 0.515021
# Epoch 788:  Error = 0.514177
# Epoch 789:  Error = 0.513336
# Epoch 790:  Error = 0.512497
# Epoch 791:  Error = 0.511661
# Epoch 792:  Error = 0.510828
# Epoch 793:  Error = 0.509997
# Epoch 794:  Error = 0.509169
# Epoch 795:  Error = 0.508344
# Epoch 796:  Error = 0.507521
# Epoch 797:  Error = 0.506701
# Epoch 798:  Error = 0.505883
# Epoch 799:  Error = 0.505068
# Epoch 800:  Error = 0.504255
# Epoch 801:  Error = 0.503445
# Epoch 802:  Error = 0.502637
# Epoch 803:  Error = 0.501832
# Epoch 804:  Error = 0.501029
# Epoch 805:  Error = 0.500229
# Epoch 806:  Error = 0.499431
# Epoch 807:  Error = 0.498635
# Epoch 808:  Error = 0.497843
# Epoch 809:  Error = 0.497052
# Epoch 810:  Error = 0.496264
# Epoch 811:  Error = 0.495478
# Epoch 812:  Error = 0.494695
# Epoch 813:  Error = 0.493914
# Epoch 814:  Error = 0.493135
# Epoch 815:  Error = 0.492359
# Epoch 816:  Error = 0.491585
# Epoch 817:  Error = 0.490814
# Epoch 818:  Error = 0.490045
# Epoch 819:  Error = 0.489278
# Epoch 820:  Error = 0.488513
# Epoch 821:  Error = 0.487751
# Epoch 822:  Error = 0.486991
# Epoch 823:  Error = 0.486234
# Epoch 824:  Error = 0.485478
# Epoch 825:  Error = 0.484725
# Epoch 826:  Error = 0.483974
# Epoch 827:  Error = 0.483225
# Epoch 828:  Error = 0.482479
# Epoch 829:  Error = 0.481735
# Epoch 830:  Error = 0.480993
# Epoch 831:  Error = 0.480253
# Epoch 832:  Error = 0.479515
# Epoch 833:  Error = 0.478780
# Epoch 834:  Error = 0.478047
# Epoch 835:  Error = 0.477316
# Epoch 836:  Error = 0.476587
# Epoch 837:  Error = 0.475860
# Epoch 838:  Error = 0.475135
# Epoch 839:  Error = 0.474413
# Epoch 840:  Error = 0.473692
# Epoch 841:  Error = 0.472974
# Epoch 842:  Error = 0.472258
# Epoch 843:  Error = 0.471544
# Epoch 844:  Error = 0.470832
# Epoch 845:  Error = 0.470122
# Epoch 846:  Error = 0.469414
# Epoch 847:  Error = 0.468708
# Epoch 848:  Error = 0.468004
# Epoch 849:  Error = 0.467302
# Epoch 850:  Error = 0.466602
# Epoch 851:  Error = 0.465905
# Epoch 852:  Error = 0.465209
# Epoch 853:  Error = 0.464515
# Epoch 854:  Error = 0.463823
# Epoch 855:  Error = 0.463134
# Epoch 856:  Error = 0.462446
# Epoch 857:  Error = 0.461760
# Epoch 858:  Error = 0.461076
# Epoch 859:  Error = 0.460394
# Epoch 860:  Error = 0.459714
# Epoch 861:  Error = 0.459036
# Epoch 862:  Error = 0.458360
# Epoch 863:  Error = 0.457686
# Epoch 864:  Error = 0.457014
# Epoch 865:  Error = 0.456343
# Epoch 866:  Error = 0.455675
# Epoch 867:  Error = 0.455008
# Epoch 868:  Error = 0.454343
# Epoch 869:  Error = 0.453681
# Epoch 870:  Error = 0.453020
# Epoch 871:  Error = 0.452360
# Epoch 872:  Error = 0.451703
# Epoch 873:  Error = 0.451048
# Epoch 874:  Error = 0.450394
# Epoch 875:  Error = 0.449742
# Epoch 876:  Error = 0.449092
# Epoch 877:  Error = 0.448444
# Epoch 878:  Error = 0.447798
# Epoch 879:  Error = 0.447153
# Epoch 880:  Error = 0.446510
# Epoch 881:  Error = 0.445869
# Epoch 882:  Error = 0.445230
# Epoch 883:  Error = 0.444593
# Epoch 884:  Error = 0.443957
# Epoch 885:  Error = 0.443323
# Epoch 886:  Error = 0.442691
# Epoch 887:  Error = 0.442060
# Epoch 888:  Error = 0.441432
# Epoch 889:  Error = 0.440805
# Epoch 890:  Error = 0.440179
# Epoch 891:  Error = 0.439556
# Epoch 892:  Error = 0.438934
# Epoch 893:  Error = 0.438314
# Epoch 894:  Error = 0.437695
# Epoch 895:  Error = 0.437078
# Epoch 896:  Error = 0.436463
# Epoch 897:  Error = 0.435850
# Epoch 898:  Error = 0.435238
# Epoch 899:  Error = 0.434628
# Epoch 900:  Error = 0.434019
# Epoch 901:  Error = 0.433412
# Epoch 902:  Error = 0.432807
# Epoch 903:  Error = 0.432204
# Epoch 904:  Error = 0.431602
# Epoch 905:  Error = 0.431001
# Epoch 906:  Error = 0.430402
# Epoch 907:  Error = 0.429805
# Epoch 908:  Error = 0.429210
# Epoch 909:  Error = 0.428616
# Epoch 910:  Error = 0.428023
# Epoch 911:  Error = 0.427433
# Epoch 912:  Error = 0.426843
# Epoch 913:  Error = 0.426256
# Epoch 914:  Error = 0.425670
# Epoch 915:  Error = 0.425085
# Epoch 916:  Error = 0.424502
# Epoch 917:  Error = 0.423921
# Epoch 918:  Error = 0.423341
# Epoch 919:  Error = 0.422762
# Epoch 920:  Error = 0.422185
# Epoch 921:  Error = 0.421610
# Epoch 922:  Error = 0.421036
# Epoch 923:  Error = 0.420464
# Epoch 924:  Error = 0.419893
# Epoch 925:  Error = 0.419324
# Epoch 926:  Error = 0.418756
# Epoch 927:  Error = 0.418189
# Epoch 928:  Error = 0.417625
# Epoch 929:  Error = 0.417061
# Epoch 930:  Error = 0.416499
# Epoch 931:  Error = 0.415939
# Epoch 932:  Error = 0.415380
# Epoch 933:  Error = 0.414822
# Epoch 934:  Error = 0.414266
# Epoch 935:  Error = 0.413711
# Epoch 936:  Error = 0.413158
# Epoch 937:  Error = 0.412606
# Epoch 938:  Error = 0.412056
# Epoch 939:  Error = 0.411507
# Epoch 940:  Error = 0.410959
# Epoch 941:  Error = 0.410413
# Epoch 942:  Error = 0.409868
# Epoch 943:  Error = 0.409325
# Epoch 944:  Error = 0.408783
# Epoch 945:  Error = 0.408242
# Epoch 946:  Error = 0.407703
# Epoch 947:  Error = 0.407165
# Epoch 948:  Error = 0.406628
# Epoch 949:  Error = 0.406093
# Epoch 950:  Error = 0.405560
# Epoch 951:  Error = 0.405027
# Epoch 952:  Error = 0.404496
# Epoch 953:  Error = 0.403966
# Epoch 954:  Error = 0.403438
# Epoch 955:  Error = 0.402911
# Epoch 956:  Error = 0.402385
# Epoch 957:  Error = 0.401861
# Epoch 958:  Error = 0.401338
# Epoch 959:  Error = 0.400816
# Epoch 960:  Error = 0.400295
# Epoch 961:  Error = 0.399776
# Epoch 962:  Error = 0.399258
# Epoch 963:  Error = 0.398742
# Epoch 964:  Error = 0.398227
# Epoch 9938:  Error = 0.028996
# Epoch 9939:  Error = 0.028993
# Epoch 9940:  Error = 0.028990
# Epoch 9941:  Error = 0.028987
# Epoch 9942:  Error = 0.028984
# Epoch 9943:  Error = 0.028981
# Epoch 9944:  Error = 0.028978
# Epoch 9945:  Error = 0.028974
# Epoch 9946:  Error = 0.028971
# Epoch 9947:  Error = 0.028968
# Epoch 9948:  Error = 0.028965
# Epoch 9949:  Error = 0.028962
# Epoch 9950:  Error = 0.028959
# Epoch 9951:  Error = 0.028956
# Epoch 9952:  Error = 0.028953
# Epoch 9953:  Error = 0.028950
# Epoch 9954:  Error = 0.028947
# Epoch 9955:  Error = 0.028944
# Epoch 9956:  Error = 0.028940
# Epoch 9957:  Error = 0.028937
# Epoch 9958:  Error = 0.028934
# Epoch 9959:  Error = 0.028931
# Epoch 9960:  Error = 0.028928
# Epoch 9961:  Error = 0.028925
# Epoch 9962:  Error = 0.028922
# Epoch 9963:  Error = 0.028919
# Epoch 9964:  Error = 0.028916
# Epoch 9965:  Error = 0.028913
# Epoch 9966:  Error = 0.028910
# Epoch 9967:  Error = 0.028907
# Epoch 9968:  Error = 0.028904
# Epoch 9969:  Error = 0.028900
# Epoch 9970:  Error = 0.028897
# Epoch 9971:  Error = 0.028894
# Epoch 9972:  Error = 0.028891
# Epoch 9973:  Error = 0.028888
# Epoch 9974:  Error = 0.028885
# Epoch 9975:  Error = 0.028882
# Epoch 9976:  Error = 0.028879
# Epoch 9977:  Error = 0.028876
# Epoch 9978:  Error = 0.028873
# Epoch 9979:  Error = 0.028870
# Epoch 9980:  Error = 0.028867
# Epoch 9981:  Error = 0.028864
# Epoch 9982:  Error = 0.028860
# Epoch 9983:  Error = 0.028857
# Epoch 9984:  Error = 0.028854
# Epoch 9985:  Error = 0.028851
# Epoch 9986:  Error = 0.028848
# Epoch 9987:  Error = 0.028845
# Epoch 9988:  Error = 0.028842
# Epoch 9989:  Error = 0.028839
# Epoch 9990:  Error = 0.028836
# Epoch 9991:  Error = 0.028833
# Epoch 9992:  Error = 0.028830
# Epoch 9993:  Error = 0.028827
# Epoch 9994:  Error = 0.028824
# Epoch 9995:  Error = 0.028821
# Epoch 9996:  Error = 0.028818
# Epoch 9997:  Error = 0.028815
# Epoch 9998:  Error = 0.028811
# Epoch 9999:  Error = 0.028808

# %% [markdown]
# On observe en le faisant run plusieurs fois que le XOR marche bien sauf quand il atteind un minimum local de loss (autour d'une loss = 25) qui se résume à une forme de croix graphiquement. S'il atteind ce minimum local, même avec 1 000 000 d'époche il ne trouve pas de bonne classification. Sinon il atteind rapidement le bon résultat.
#
# Quand on mets les weights et inputs initialisé à 0, il ne se passe rien (et cela ne marche pas). C'est logique car les gradients sont nuls alors.
# Tentative de faire le XOR en pytorch :

# %%
import torch as t
import torch.nn as nn

model = nn.Sequential(
    nn.Linear(nInputs,nHiddens),
    nn.Sigmoid(),
    nn.Linear(nHiddens,nOutputs),
    nn.Sigmoid()
    )

# %%
from torch.optim import SGD
 
# epoch : 9980; loss: 0.024
# epoch : 9981; loss: 0.024
# epoch : 9982; loss: 0.024
# epoch : 9983; loss: 0.024
# epoch : 9984; loss: 0.024
# epoch : 9985; loss: 0.024
# epoch : 9986; loss: 0.024
# epoch : 9987; loss: 0.024
# epoch : 9988; loss: 0.024
# epoch : 9989; loss: 0.024
# epoch : 9990; loss: 0.024
# epoch : 9991; loss: 0.024
# epoch : 9992; loss: 0.024
# epoch : 9993; loss: 0.024
# epoch : 9994; loss: 0.024
# epoch : 9995; loss: 0.024
# epoch : 9996; loss: 0.024
# epoch : 9997; loss: 0.024
# epoch : 9998; loss: 0.024
# epoch : 9999; loss: 0.024
# epoch : 10000; loss: 0.024
# Finished Training

# %%
model(t.tensor(np.array([0,0]).T).float())
# Out:
# tensor([0.9651], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# On observe que cela marche très bien aussi! Yahouuu

# %% [markdown]
# **Optional questions**
#
# 2. *Weight decay* constraint
#
# As nothing constrains the weights in the network, we can note that usually all weights vector given a multiplicative factor might be equivalent, which can stall the learning (and lead to exploding weights). The *weight decay* allows to regularize the learning by penalizing weights with a too wide amplitude. The idea is to add this constraint as a term to the final loss (which leads to an indirect "pressure" on the learning process. Therefore, the final loss will be defined as
#
# $$
# \begin{equation}
# \mathcal{L}_{final}=\mathcal{L_D} + \lambda \sum_{l} \sum_{i} \sum_{j} \left( W_{ij}^{l} \right)^{2}
# \end{equation}
# $$
#
# where the parameter $\lambda$ controls the relative importance of the two terms.
#
# 3. *Momentum* in learning
#
# Usually, in complex problems, the gradient can be very noisy and, therefore, the learning might oscillate widely. In order to reduce this problem, we can *smooth* the different gradient updates by retaining the values of the gradient at each iteration and then performing an update based on the latest gradient $\delta_{i}^{t}$ and the gradient at the previous iteration $\delta_{i}^{t-1}$. Therefore, a gradient update is applied as
#
# $$
# \begin{equation}
# \delta_{final}^{t} = \delta_{i}^{t} + m.\delta_{i}^{t-1}
# \end{equation}
# $$
#
# with $m$ the momentum parameter, which control the amount of gradient smoothing.

# %% [markdown]
# ## 3-layer audio classification
#
# Finally, we will attack a complete audio classification problem and try to perform neural network learning on a set of audio files. The data structure will be the same as the one used for parts 1 and 2. As discussed during the courses, even though a 2-layer neural network can provide non-linear boundaries, it can not perform "holes" inside those regions. In order to obtain an improved classification, we will now rely on a 3-layer neural network. The modification to the code of section 3.2 should be minimal, as the back-propagation will be similar for the new layer as one of the two others. We do not develop the math here as it is simply a re-application of the previous rules with an additional layer (which derivatives you should have generalized in the previous exercise).
#
# However, up until now, we only performed *binary classification* problems, but this time we need to obtain a decision rule for multiple classes. Therefore, we cannot rely on simply computing the distance between desired patterns and the obtained binary value. The idea here is to rely on the *softmax regression*, by considering classes as a vector of probabilities. The desired answers will therefore be considered as a set of *probabilities*, where the desired class is $1$ and the others are $0$ (called *one-hot* representation). Then, the cost function will rely on the softmax formulation
#
# $$
# \begin{equation}
# \mathcal{L_D}(\theta) = - \frac{1}{m} \left[ \sum_{i=1}^{m} \sum_{j=1}^{k} 1\left\{y^{(i)} = j\right\} log \frac{e^{\theta_{j}^{T} x^{(i)}}}{\sum_{l=1}^{k} e^{ \theta_{l}^{T} x^{(i)} }}  \right]
# \end{equation}
# $$
#
# Therefore, we compute the output of the softmax by taking
#
# $$
# \begin{equation}
# p(y^{(i)} = j | x^{(i)}; \theta) = \frac{e^{\theta_{j}^{T} x^{(i)}}}{\sum_{l=1}^{k} e^{ \theta_{l}^{T} x^{(i)}} }
# \end{equation}
# $$
#
# By taking derivatives, we can show that the gradient of the softmax layer is
#
# $$
# \begin{equation}
# \nabla_{\theta_{j}} \mathcal{L_D}(\theta) = - \frac{1}{m} \sum_{i=1}^{m}{ \left[ x^{(i)} \left( 1\{ y^{(i)} = j\}  - p(y^{(i)} = j \mid x^{(i)}, \theta) \right) \right]}
# \end{equation}
# $$

# %% [markdown]
# ### Sweet activation functions
#
# As discussed in the course, the interest of stacking layers is that there is an _activation function_, which allows non-linear interactions between the dimensions (and avoids to only compute a single huge affine transform). Although the `sigmoid` function has been historically the most used, there has been some large developments since. Notably the `ReLU` (Rectified Linear Unit) is one of the major difference in modern networks (we will see more about that in a later course)

# %%
# Function for computing the Sigmoid activation
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def dsigmoid(a):
    return a * (1.0 - a)
# Function for computing the ReLU activation
def relu(x):
    return np.maximum(0, x)
def drelu(x):
    return 1 / (1 + np.exp(-x))
# Function for computing the Tanh activation
def tanh(x):
    return np.tanh(x);
def dtanh(x): 
    return np.cosh(x) ^ -2

# %% [markdown]
# Here, we plot some simple examples of what these activation functions look like. You can try to rely on these functions in your previous training code and witness the differences in training.

# %%
from helper_plot import prep_plots, finalize_plots
funcs = [('sigmoid',sigmoid,'red'), ('tanh',tanh,'orange'), ('relu',relu,'yellow')]
axes = prep_plots([funcs[0][0], funcs[1][0], funcs[2][0]], fig_size=(18,5), fig_num=1)
x_plot = np.linspace(-5,5,100)
np.maximum(0, x_plot)
for f in range(3):
    axes[f].plot(x_plot, funcs[f][1](x_plot), color=funcs[f][2], linewidth=4, label=funcs[f][0])
finalize_plots(axes, fig_title="Activation functions")

# %% [markdown]
# ## Coding the whole network from scratch
#
# You should now have all the tools necessary to apply neural networks from scratch to a more complex problem. In the following exercise, we simply removed any guideline code, and you need to code all the procedure for training a NN and **apply it to audio data**. You will use the spectral features discussed in the previous exercise as an input.
#
# ***
#
# **Exercise**
#
#   1. Based on the previous neural network, upgrade the code to a 3-layer neural network
#   2. Implement the *softmax regression* on top of your 3-layer network
#   3. Use the provided code to perform classification on a pre-defined set of features
#   4. As previously, change the set of features to assess their different accuracies
#   5. Evaluate the neural network accuracy for all features combinations
#   6. What happens if the learning rate is too large ? What is this phenomenon ?
#   7. (Optional) Perform a more advanced visualization of the learning process.
#
# ***

# %%
# Iterate for a fixed number of iterations
for epoch in range(500):
    
    ######################
    # YOUR CODE GOES HERE
    ######################
    
    print('Epoch %3d:  Error = %f\n' % epoch, TSS);
    if TSS < TSS_Limit:
        break
plo_boundary(np.concatenate(bias1, weights1), epoch, '-');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [218], line 8
#       1 # Iterate for a fixed number of iterations
#       2 for epoch in range(500):
#       3
#       4     ######################
#       5     # YOUR CODE GOES HERE
#       6     ######################
# ----> 8     print('Epoch %3d:  Error = %f\n' % epoch, TSS);
#       9     if TSS < TSS_Limit:
#      10         break
#
# TypeError: not enough arguments for format string

# %% [markdown]
# ## Using Pytorch to enjoy life
#
# Up to now, we have been writing every operations by ourselves (in order to better understand the mathematics behind NN). However, there exists of course some simplifying libraries that provide large simplifications to this question.
#
# One of the most powerful and complete library of this sort is `Pytorch`, which has been developed for several years (even prior to the recent boom of deep learning). `Pytorch` provides a large set of pre-coded layers, but also **computational graphs** and **autograd**, which are very powerful paradigms allowing to define complex operators and automatically taking derivatives.
#
# ### Defining our network
#
# When building neural networks we frequently think of arranging the computation into layers, some of which have learnable parameters which will be optimized during learning. In `PyTorch`, the `nn` package provides higher-level abstractions over raw computational graphs that are useful for building neural networks. The `nn` package defines a set of `Modules`, which are roughly equivalent to neural network layers. A `Module` receives input `Tensors` and computes output `Tensors`, but may also hold internal state such as `Tensors` containing learnable parameters. The nn package also defines a set of useful loss functions that are commonly used when training neural networks.
#
# In the following example, we use the `nn` package to show how easy it is to instantiate our previous three-layers network

# %%
import torch
# Define the input dimensions
in_size = 1000
# Number of neurons in a layer
hidden_size = 100
# Output (target) dimension
output_size = 10
# Use the nn package to define our model and loss function.
model = torch.nn.Sequential(
    torch.nn.Linear(in_size, hidden_size),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_size, hidden_size),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_size, output_size),
    torch.nn.Softmax(dim=1)
)

# %% [markdown]
# ### Optimizing the network
#
# Up to this point we have updated the weights of our models by manually performing the gradient descent algorithm (changing the parameters vectors). Although this is not a huge burden for simple optimization algorithms like stochastic gradient descent, in practice we often train neural networks using more sophisticated optimizers like AdaGrad, RMSProp or Adam (that we will see later in this course)
#
# The `optim` package in PyTorch abstracts the idea of an optimization algorithm and provides implementations of commonly used optimization algorithms, and greatly simplfies the training loop associated with training a neural network.
#
# For the sake of presentation we will use random inputs $\mathbf{x}$ that should be matched with random outputs $\mathbf{y}$

# %%
batch_size = 64
D_in = 1000
D_out = 10
N= 6
# Create random Tensors to hold inputs and outputs
x = torch.randn(N, D_in)
y = torch.randn(N, D_out)

# %% [markdown]
# In the following example we optimize the model using the Adam algorithm provided by the `optim` package, based on a `MSE` loss.

# %%
# Learning rate
learning_rate = 1e-4
# Loss function that we will use
loss_fn = torch.nn.MSELoss(reduction='sum')
# Optimizer to fit the weights of the network
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
for t in range(500):
    # Forward pass: compute predicted y by passing x to the model.
    y_pred = model(x)
    # Compute the loss.
    loss = loss_fn(y_pred, y)
    # Before the backward pass, zero all of the network gradients
    optimizer.zero_grad()
    # Backward pass: compute gradient of the loss with respect to parameters
    loss.backward()
    # Calling the step function to update the parameters
    optimizer.step()

# %% [markdown]
# ## Using Pytorch to classify audio
#
# Now that we know the main components of `Pytorch` to define and optimize networks, your assignement is to define a complete classification problem from audio data, by relying on this toolbox
#
# ***
#
# **Exercise**
#
#   1. Use `Pytorch` to define a model for audio classification
#   2. Import the audio features dataset and check that your model produces an output
#   3. Write the optimization loop (think carefully about the _loss function_
#   4. As previously, change the set of features to assess their different accuracies
#   5. Think of how you could use more complex features (time series, audio, STFT) to classify your data
#
# ***

# %%
import torch as t
import torch.nn as nn
